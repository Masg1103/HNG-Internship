# %%
# !pip install folium geopy pandas
# !pip install folium geopy
# !pip install selenium pillow

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import BallTree
import folium
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import time
from selenium import webdriver
from PIL import Image
import os
from folium.plugins import MarkerCluster
from IPython.display import display, IFrame

import requests
from scipy.stats import zscore
from geopy.distance import geodesic
from sklearn.preprocessing import StandardScaler

# %%
# Print the current working directory
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\SERWAH\Desktop\HNG Internship\Stage 1

# %%
# Load the dataset
osun_data = pd.read_csv('OSUN_crosschecked.csv')
polling_data = pd.read_csv('polling-units.csv')

# Read the first line
osun_data.head(1)
# Out:
#   State             LGA   Ward       PU-Code          PU-Name  \
# 0  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-001  TOWN HALL IWARA
#
#    Accredited_Voters  Registered_Voters  Results_Found  Transcription_Count  \
# 0                181                942           True                   -1
#
#    Result_Sheet_Stamped  Result_Sheet_Corrected  Result_Sheet_Invalid  \
# 0                 False                   False                 False
#
#    Result_Sheet_Unclear Result_Sheet_Unsigned  APC   LP  PDP  NNPP  \
# 0                 False               UNKNOWN   44  273    0     0
#
#                                         Results_File
# 0  https://inec-cvr-cache.s3.eu-west-1.amazonaws....

# %%
polling_data.head(1)
# Out:
#                           PU-Name         Ward Local Government Name State  \
# 0  LGEA SCHOOL INABE, INABE/EFOJA  OLAMABORO V             OLAMABORO  KOGI
#
#    Latitude  Longitude
# 0  7.178359   7.577163

# %%
# List of columns to drop
columns_to_drop = [
    'Results_Found', 'Transcription_Count', 'Result_Sheet_Stamped', 
    'Result_Sheet_Corrected', 'Result_Sheet_Invalid', 
    'Result_Sheet_Unclear', 'Result_Sheet_Unsigned', 'Results_File'
]

# Drop the columns
osun_data.drop(columns=columns_to_drop, inplace=True)
osun_data.head(1)
# Out:
#   State             LGA   Ward       PU-Code          PU-Name  \
# 0  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-001  TOWN HALL IWARA
#
#    Accredited_Voters  Registered_Voters  APC   LP  PDP  NNPP
# 0                181                942   44  273    0     0

# %%
osun_data.shape
# Out:
# (2248, 11)

# %%
# Check the column names of both dataframes
print(osun_data.columns)
print(polling_data.columns)
# Out:
# Index(['State', 'LGA', 'Ward', 'PU-Code', 'PU-Name', 'Accredited_Voters',
#        'Registered_Voters', 'APC', 'LP', 'PDP', 'NNPP'],
#       dtype='object')
# Index(['PU-Name', 'Ward', 'Local Government Name', 'State', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# Ensure that the column names for merging are consistent
osun_data.rename(columns={'State': 'State', 'Ward': 'Ward', 'PU-Name': 'PU-Name', 'LGA': 'LGA'}, inplace=True)
polling_data.rename(columns={'State': 'State', 'Ward': 'Ward', 'PU-Name': 'PU-Name', 'Local Government Name': 'LGA'}, inplace=True)

# %%
# Check the number of unique values in key columns before merging
print(f"Unique values in Delta data (State, Ward, PU-Name, LGA): {osun_data[['State', 'Ward', 'PU-Name', 'LGA']].nunique()}")
print(f"Unique values in Polling units (State, Ward, PU-Name, LGA): {polling_data[['State', 'Ward', 'PU-Name', 'LGA']].nunique()}")
# Out:
# Unique values in Delta data (State, Ward, PU-Name, LGA): State         1
# Ward        324
# PU-Name    2127
# LGA          30
# dtype: int64
# Unique values in Polling units (State, Ward, PU-Name, LGA): State          37
# Ward         8463
# PU-Name    170997
# LGA           768
# dtype: int64

# %%
# Merge the datasets on 'state', 'ward', and 'pu_name'
merged_data = pd.merge(osun_data, polling_data, on=['State', 'Ward', 'LGA', 'PU-Name' ])

# Check the shape of the merged data
print(f"Shape of merged data: {merged_data.shape}")
# Out:
# Shape of merged data: (2234, 13)

# %%
# # Merge the datasets on 'state', 'ward', and 'pu_code'
# merged_data = pd.merge(delta_data, polling_data, on=['State', 'Ward', 'PU-Name', 'LGA'])

# # Check the shape of the merged data
# print(f"Shape of merged data: {merged_data.shape}")

# %%
# Check the first few rows of the merged data
merged_data.head(2)
# Out:
#   State             LGA   Ward       PU-Code              PU-Name  \
# 0  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-001      TOWN HALL IWARA
# 1  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-003  L.A. SCHOOL, IWIKUN
#
#    Accredited_Voters  Registered_Voters  APC   LP  PDP  NNPP  Latitude  \
# 0                181                942   44  273    0     0  7.466182
# 1                245                881   40   11  175     1  7.586975
#
#    Longitude
# 0   4.678075
# 1   4.629450

# %%
# Check for missing values in 'latitude' and 'longitude' columns
merged_data[['Latitude', 'Longitude']].isnull().sum()
# Out:
# Latitude     264
# Longitude    264
# dtype: int64

# %%
# Remove rows with NaN values in latitude and longitude
merged_data = merged_data.dropna(subset=['Latitude', 'Longitude'])

# %%
# Check for missing values in 'latitude' and 'longitude' columns
merged_data[['Latitude', 'Longitude']].isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# dtype: int64

# %%
# Reset the index of merged_data to ensure consistent indexing
merged_data.reset_index(drop=True, inplace=True)

# %%
# Convert latitude and longitude to radians for BallTree
merged_data['Latitude_rad'] = np.radians(merged_data['Latitude'])
merged_data['Longitude_rad'] = np.radians(merged_data['Longitude'])

# %%
# Prepare the data for BallTree
coords = np.vstack((merged_data['Latitude_rad'], merged_data['Longitude_rad'])).T

# %%
coords
# Out:
# array([[0.13030947, 0.0816478 ],
#        [0.13241769, 0.08079914],
#        [0.13694432, 0.07832866],
#        ...,
#        [0.1359045 , 0.07955204],
#        [0.1359045 , 0.07955204],
#        [0.1359045 , 0.07955204]])

# %%
# Create BallTree
tree = BallTree(coords, metric='haversine')

# %%
# Define radius (1 km in radians)
radius = 1 / 6371.0  # 1 km / Earth's radius in km

# %%
# Identify neighbouring polling units
def find_neighbours_balltree(tree, coords, radius):
    neighbours = {}
    for i, coord in enumerate(coords):
        indices = tree.query_radius([coord], r=radius)[0]
        neighbours[i] = indices[indices != i]  # Exclude the point itself
    return neighbours

# %%
# Find neighbours using BallTree
neighbours = find_neighbours_balltree(tree, coords, radius)

# %%
# Showing lines of the output
neighbours
# Out:
# {0: array([73, 74, 75, 76, 70], dtype=int64),
#  1: array([36, 34, 29, 32, 37, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  2: array([  52,   45,   56, 1184], dtype=int64),
#  3: array([], dtype=int64),
#  4: array([], dtype=int64),
#  5: array([ 730, 1274,   38,  800,  850,  688,  706, 1943,  668,  727],
#        dtype=int64),
#  6: array([   7,   10,   27,   33,   12,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  7: array([   6,   10,   27,   33,   12,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  8: array([1051, 1462, 1031, 1050, 1015, 1100, 1117, 1044, 1045, 1948, 1123,
#         1124, 1125, 1020, 1120, 1121, 1012, 1065, 1059, 1006,  210, 1068,
#         1090, 1046, 1113, 1094, 1481, 1111, 1055, 1461, 1119, 1060, 1069,
#         1062], dtype=int64),
#  9: array([1013], dtype=int64),
#  10: array([   6,    7,   27,   33,   12,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  11: array([  26, 1039, 1030, 1036, 1080, 1035, 1038, 1029, 1285, 1063, 1064,
#         1089, 1065, 1059, 1037, 1109, 1108,  864, 1478, 1034,  339, 1027,
#         1062,  865, 1118], dtype=int64),
#  12: array([   6,    7,   10,   27,   33,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  13: array([], dtype=int64),
#  14: array([   6,    7,   10,   27,   33,   12,   16,   17,   23, 1919],
#        dtype=int64),
#  15: array([1081, 1007,   31, 1946, 1086], dtype=int64),
#  16: array([   6,    7,   10,   27,   33,   12,   14,   17,   23, 1919],
#        dtype=int64),
#  17: array([   6,    7,   10,   27,   33,   12,   14,   16,   23, 1919],
#        dtype=int64),
#  18: array([], dtype=int64),
#  19: array([], dtype=int64),
#  20: array([], dtype=int64),
#  21: array([1516, 1557, 1533, 1601, 1537, 1556, 1599, 1603, 1555, 1594, 1520,
#         1521, 1522, 1525,  282, 1577, 1526, 1527, 1528, 1553, 1569, 1575,
#         1576, 1592, 1595, 1590], dtype=int64),
#  22: array([77], dtype=int64),
#  23: array([   6,    7,   10,   27,   33,   12,   14,   16,   17, 1919],
#        dtype=int64),
#  24: array([], dtype=int64),
#  25: array([], dtype=int64),
#  26: array([1039, 1030, 1036, 1080, 1035, 1038,   11, 1029, 1285], dtype=int64),
#  27: array([   6,    7,   10,   33,   12,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  28: array([], dtype=int64),
#  29: array([36,  1, 34, 32, 37, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  30: array([], dtype=int64),
#  31: array([  15, 1081, 1007, 1946, 1086], dtype=int64),
#  32: array([36,  1, 34, 29, 37, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  33: array([   6,    7,   10,   27,   12,   14,   16,   17,   23, 1919],
#        dtype=int64),
#  34: array([36,  1, 29, 32, 37, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  35: array([ 646,  647,  655, 1004,  656,  624, 1460, 1005], dtype=int64),
#  36: array([ 1, 34, 29, 32, 37, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  37: array([36,  1, 34, 29, 32, 39, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  38: array([   5,  730, 1274,  800,  850,  688,  706, 1943,  668,  727],
#        dtype=int64),
#  39: array([36,  1, 34, 29, 32, 37, 40, 41, 43, 47, 48, 49, 64], dtype=int64),
#  40: array([36,  1, 34, 29, 32, 37, 39, 41, 43, 47, 48, 49, 64], dtype=int64),
#  41: array([36,  1, 34, 29, 32, 37, 39, 40, 43, 47, 48, 49, 64], dtype=int64),
#  42: array([], dtype=int64),
#  43: array([36,  1, 34, 29, 32, 37, 39, 40, 41, 47, 48, 49, 64], dtype=int64),
#  44: array([1288, 1287], dtype=int64),
#  45: array([  52,    2,   56, 1184], dtype=int64),
#  46: array([], dtype=int64),
#  47: array([36,  1, 34, 29, 32, 37, 39, 40, 41, 43, 48, 49, 64], dtype=int64),
#  48: array([36,  1, 34, 29, 32, 37, 39, 40, 41, 43, 47, 49, 64], dtype=int64),
#  49: array([36,  1, 34, 29, 32, 37, 39, 40, 41, 43, 47, 48, 64], dtype=int64),
#  50: array([], dtype=int64),
#  51: array([], dtype=int64),
#  52: array([   2,   45,   56, 1184], dtype=int64),
#  53: array([], dtype=int64),
#  54: array([1043,   68, 1095], dtype=int64),
#  55: array([1026, 1011, 1008, 1054, 1053, 1052], dtype=int64),
#  56: array([  52,    2,   45, 1184], dtype=int64),
#  57: array([394], dtype=int64),
#  58: array([1337, 1338, 1315, 1316, 1317, 1322, 1314], dtype=int64),
#  59: array([705], dtype=int64),
#  60: array([1749,  714], dtype=int64),
#  61: array([661], dtype=int64),
#  62: array([1760, 1764, 1958, 1959, 1827, 1822, 1636, 1831, 1834, 1629, 1821,
#          931,  244, 1836, 1910], dtype=int64),
#  63: array([138, 137, 163,  87], dtype=int64),
#  64: array([36,  1, 34, 29, 32, 37, 39, 40, 41, 43, 47, 48, 49], dtype=int64),
#  65: array([], dtype=int64),
#  66: array([1639, 1888, 1967, 1968, 1969, 1643, 1680, 1355, 1655, 1656, 1661,
#         1681, 1864,  625, 1676, 1900,  328,  620, 1669, 1471, 1663, 1668,
#         1667,  387, 1825, 1644,  330, 1646, 1905], dtype=int64),
#  67: array([1015, 1100, 1044, 1045, 1948, 1020, 1063, 1064, 1089, 1025, 1065,
#         1112, 1059, 1037, 1109, 1108, 1006, 1478,  210, 1068, 1090, 1113,
#           69, 1094, 1481, 1111, 1024,  339, 1115, 1027, 1461, 1119, 1060,
#         1069, 1062, 1102, 1073, 1058, 1074, 1104, 1076, 1075, 1105, 1106,
#         1107, 1110, 1061, 1070, 1071, 1072, 1066], dtype=int64),
#  68: array([1043,   54, 1095], dtype=int64),
#  69: array([1015, 1100, 1044, 1045, 1948, 1020, 1063, 1064, 1089, 1025, 1065,
#         1112, 1059, 1037, 1109, 1108, 1006, 1478,  210, 1068, 1090, 1113,
#         1094,   67, 1481, 1111, 1024,  339, 1115, 1027, 1461, 1119, 1060,
#         1069, 1062, 1102, 1073, 1058, 1074, 1104, 1076, 1075, 1105, 1106,
#         1107, 1110, 1061, 1070, 1071, 1072, 1066], dtype=int64),
#  70: array([73, 74, 75, 76,  0], dtype=int64),
#  71: array([72], dtype=int64),
#  72: array([71], dtype=int64),
#  73: array([74,  0, 70], dtype=int64),
#  74: array([73,  0, 70], dtype=int64),
#  75: array([76,  0, 70], dtype=int64),
#  76: array([75,  0, 70], dtype=int64),
#  77: array([22], dtype=int64),
#  78: array([1964, 1963, 1822, 1962, 1961, 1364, 1636, 1960,  412, 1362, 1361,
#         1363, 1853, 1637, 1629,  931,  244, 1921, 1083, 1082, 1841, 1840,
#         1839, 1838, 1837, 1832, 1662, 1965, 1966, 1835,  364, 1638, 1426],
#        dtype=int64),
#  79: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   83,   82,
#          790,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  80: array([  93, 1608, 1244,   81,  122,  121,  106,  391], dtype=int64),
#  81: array([  93, 1608, 1244,   80,  122,  121,  106,  391], dtype=int64),
#  82: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   83,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  83: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   82, 1138,
#          790,   79,  120,  119,  126, 1251,  138,  137,  116,   87],
#        dtype=int64),
#  84: array([], dtype=int64),
#  85: array([  90,   89,   88,   94,   95,   96, 1608,   86,   83,   82, 1138,
#          790,   79,  120,  119,  126, 1251,  138,  137,  116,   87],
#        dtype=int64),
#  86: array([  90,   89,   88,   94,   95,   96, 1608,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  87: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   83,   82,
#          790,   79, 1251,   63,  138,  137,  163,  122,  121,  116,  106,
#          391,   91], dtype=int64),
#  88: array([  90,   89,   94,   95,   96, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  89: array([  90,   88,   94,   95,   96, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  90: array([  89,   88,   94,   95,   96, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  91: array([  90,   89,   88,   94,   95,   96, 1608,   86,   82,  790,   79,
#         1251,  138,  137,  163,  122,  121,  106,  391,   87], dtype=int64),
#  92: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  131,  129,  142, 1258,
#          140,  139, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  93: array([ 81,  80, 122, 121, 391], dtype=int64),
#  94: array([  90,   89,   88,   95,   96, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  95: array([  90,   89,   88,   94,   96, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  96: array([  90,   89,   88,   94,   95, 1608,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,  116,  106,   87,   91],
#        dtype=int64),
#  97: array([ 111,  103, 1284,   98,  104,  113,  294,  739], dtype=int64),
#  98: array([ 111,  103, 1284,   97,  104,  113,  294,  739], dtype=int64),
#  99: array([687, 679, 707, 794, 691, 910, 906, 692, 697, 701, 670, 715, 671,
#         672, 675, 751, 685, 676, 680, 530, 677, 681, 683, 693, 914],
#        dtype=int64),
#  100: array([469, 471, 470], dtype=int64),
#  101: array([105], dtype=int64),
#  102: array([], dtype=int64),
#  103: array([ 108,  111, 1284,   97,   98,  104,  113,  294,  828], dtype=int64),
#  104: array([ 111,  103, 1284,   97,   98,  113,  294,  739], dtype=int64),
#  105: array([739, 101], dtype=int64),
#  106: array([  90,   89,   88,   94,   95,   96, 1608,   86,   82,  790,   79,
#           81,   80, 1251,  138,  137,  163,  122,  121,  391,   87,   91],
#        dtype=int64),
#  107: array([1284,  197], dtype=int64),
#  108: array([111, 103, 828], dtype=int64),
#  109: array([], dtype=int64),
#  110: array([ 704,  588,  589,  590, 1933,  594,  599,  557,  563,  558,  559,
#          552,  553,  918,  555,  510,  513,  514,  515,  522,  525,  521,
#          528,  524,  520,  526,  527,  523,  568,  898,  569, 1329, 1684,
#         1942,  542,  543,  711, 1934,  509,  529,  534,  535,  536,  537,
#          554,  564,  565,  572,  573,  580,  581,  591,  595,  596,  556],
#        dtype=int64),
#  111: array([ 108,  103, 1284,   97,   98,  104,  113,  294,  828], dtype=int64),
#  112: array([1399, 1386, 1390, 1391, 1954], dtype=int64),
#  113: array([ 111,  103, 1284,   97,   98,  104,  294,  739], dtype=int64),
#  114: array([1256, 1300, 1233, 1264, 1313, 1344,  131,  129,  142, 1258,  140,
#          139,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  115: array([ 796,  550, 1939,  901, 1952,  541,  902, 1941,  578, 1937, 1936,
#          549,  545], dtype=int64),
#  116: array([  90,   89,   88,   94,   95,   96,   86,   85,   83,   82,  790,
#           79,  120,  119,  126, 1251,  138,  137,   87], dtype=int64),
#  117: array([1611], dtype=int64),
#  118: array([], dtype=int64),
#  119: array([  90,   89,   88,   94,   95,   96,   86,   85,   83,   82,  790,
#           79,  120,  765,  126, 1251,  116], dtype=int64),
#  120: array([  90,   89,   88,   94,   95,   96,   86,   85,   83,   82,  790,
#           79,  119,  765,  126, 1251,  116], dtype=int64),
#  121: array([  93, 1608,   81,   80,  138,  137,  163,  122,  106,  391,   87,
#           91], dtype=int64),
#  122: array([  93, 1608,   81,   80,  138,  137,  163,  121,  106,  391,   87,
#           91], dtype=int64),
#  123: array([], dtype=int64),
#  124: array([], dtype=int64),
#  125: array([], dtype=int64),
#  126: array([  90,   89,   88,   94,   95,   96,   86,   85,   83,   82,  790,
#           79,  120,  119,  765, 1251,  116], dtype=int64),
#  127: array([], dtype=int64),
#  128: array([], dtype=int64),
#  129: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  131,  142, 1258,  140,
#          139,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  130: array([], dtype=int64),
#  131: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  129,  142, 1258,  140,
#          139,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  132: array([], dtype=int64),
#  133: array([ 144, 1328], dtype=int64),
#  134: array([332, 135, 337, 365], dtype=int64),
#  135: array([332, 134, 337, 365], dtype=int64),
#  136: array([], dtype=int64),
#  137: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   83,   82,
#          790,   79, 1251,   63,  138,  163,  122,  121,  116,  106,  391,
#           87,   91], dtype=int64),
#  138: array([  90,   89,   88,   94,   95,   96, 1608,   86,   85,   83,   82,
#          790,   79, 1251,   63,  137,  163,  122,  121,  116,  106,  391,
#           87,   91], dtype=int64),
#  139: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  131,  129,  142, 1258,
#          140,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  140: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  131,  129,  142, 1258,
#          139,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  141: array([], dtype=int64),
#  142: array([1256,  114, 1300, 1233, 1264, 1313, 1344,  131,  129, 1258,  140,
#          139,   92, 1266, 1232, 1230,  795, 1229, 1319, 1259, 1342],
#        dtype=int64),
#  143: array([], dtype=int64),
#  144: array([ 133, 1328], dtype=int64),
#  145: array([], dtype=int64),
#  146: array([], dtype=int64),
#  147: array([149], dtype=int64),
#  148: array([], dtype=int64),
#  149: array([147], dtype=int64),
#  150: array([1415, 1419, 1420,  164, 1422, 1423, 1377, 1387, 1371, 1442, 1449,
#         1413, 1437, 1433, 1434, 1378, 1412, 1450,  185, 1424, 1421, 1385,
#         1379, 1384, 1425, 1404, 1411, 1402, 1406, 1428, 1374, 1427, 1430,
#         1429, 1405, 1432], dtype=int64),
#  151: array([1441, 1407,  160, 1396, 1395,  156, 1403, 1397,  157, 1389, 1417,
#         1393, 1392, 1444, 1618, 1394, 1398], dtype=int64),
#  152: array([1616,  153], dtype=int64),
#  153: array([ 152, 1616], dtype=int64),
#  154: array([161], dtype=int64),
#  155: array([], dtype=int64),
#  156: array([1441, 1407,  160, 1396, 1395, 1403, 1397,  157, 1389, 1417, 1393,
#          151, 1392, 1444, 1618, 1394, 1398], dtype=int64),
#  157: array([1441, 1407,  160, 1396, 1395,  156, 1403, 1397, 1389, 1417, 1393,
#          151, 1392, 1444, 1618, 1394, 1398], dtype=int64),
#  158: array([], dtype=int64),
#  159: array([1267, 1242, 1268, 1270, 1275, 1276, 1231,  773], dtype=int64),
#  160: array([1441, 1407, 1396, 1395,  156, 1403, 1397,  157, 1417,  151, 1392,
#         1444, 1618, 1394, 1398], dtype=int64),
#  161: array([154], dtype=int64),
#  162: array([], dtype=int64),
#  163: array([ 63, 138, 137, 122, 121, 106, 391,  87,  91], dtype=int64),
#  164: array([1415,  150, 1419, 1420, 1422, 1423, 1377, 1387, 1371, 1442, 1449,
#         1413, 1437, 1433, 1434, 1378, 1412, 1450,  185, 1424, 1421, 1385,
#         1379, 1384, 1425, 1404, 1411, 1402, 1406, 1428, 1374, 1427, 1430,
#         1429, 1405, 1432], dtype=int64),
#  165: array([], dtype=int64),
#  166: array([], dtype=int64),
#  167: array([], dtype=int64),
#  168: array([], dtype=int64),
#  169: array([178, 170], dtype=int64),
#  170: array([169, 172, 173], dtype=int64),
#  171: array([], dtype=int64),
#  172: array([173, 170], dtype=int64),
#  173: array([172, 170], dtype=int64),
#  174: array([177, 179, 181], dtype=int64),
#  175: array([840, 834, 802, 833, 824, 829, 887, 806, 807, 830, 832, 836, 841,
#         827], dtype=int64),
#  176: array([1607, 1610], dtype=int64),
#  177: array([174, 179, 181], dtype=int64),
#  178: array([169], dtype=int64),
#  179: array([174, 177, 181], dtype=int64),
#  180: array([], dtype=int64),
#  181: array([174, 177, 179], dtype=int64),
#  182: array([1805, 1807, 1829, 1806, 1782, 1795, 1796, 1833, 1830, 1804, 1852,
#         1957, 1826, 1836, 1766, 1776, 1768, 1769, 1770, 1771, 1809, 1774,
#         1767, 1773, 1772, 1808, 1777, 1915, 1775, 1778, 1780, 1781, 1779],
#        dtype=int64),
#  183: array([1609,  184,  186,  188,  189], dtype=int64),
#  184: array([ 183, 1609,  186,  189], dtype=int64),
#  185: array([1415,  150, 1419, 1420,  164, 1422, 1423, 1387, 1371, 1442, 1413,
#         1433, 1434, 1412, 1448, 1424, 1421, 1447, 1385, 1379, 1384, 1425,
#         1359, 1360, 1367, 1365, 1369, 1368, 1366, 1404, 1411, 1402, 1406,
#         1428, 1374, 1427, 1430, 1429, 1405, 1432, 1393], dtype=int64),
#  186: array([ 183, 1609,  184,  189], dtype=int64),
#  187: array([1484, 1485, 1470, 1479, 1482, 1483], dtype=int64),
#  188: array([ 183, 1609], dtype=int64),
#  189: array([ 183, 1609,  184,  186], dtype=int64),
#  190: array([192], dtype=int64),
#  191: array([193, 195], dtype=int64),
#  192: array([190], dtype=int64),
#  193: array([191, 195], dtype=int64),
#  194: array([199, 218, 215, 202, 203, 206], dtype=int64),
#  195: array([191, 193], dtype=int64),
#  196: array([], dtype=int64),
#  197: array([107], dtype=int64),
#  198: array([], dtype=int64),
#  199: array([218, 215, 202, 203, 206, 194], dtype=int64),
#  200: array([204, 205], dtype=int64),
#  201: array([], dtype=int64),
#  202: array([199, 218, 215, 203, 206, 194], dtype=int64),
#  203: array([199, 218, 215, 202, 206, 194], dtype=int64),
#  204: array([200], dtype=int64),
#  205: array([200], dtype=int64),
#  206: array([199, 218, 215, 202, 203, 194], dtype=int64),
#  207: array([208], dtype=int64),
#  208: array([207], dtype=int64),
#  209: array([], dtype=int64),
#  210: array([1015, 1100, 1044, 1045, 1948, 1020, 1063, 1064, 1089, 1025, 1065,
#         1112, 1059, 1037, 1109, 1108,    8, 1006, 1478, 1068, 1090, 1113,
#           69, 1094,   67, 1481, 1111, 1024,  339, 1115, 1027, 1461, 1119,
#         1060, 1069, 1062, 1102, 1073, 1058, 1074, 1104, 1076, 1075, 1105,
#         1106, 1107, 1110, 1061, 1070, 1071, 1072, 1066], dtype=int64),
#  211: array([], dtype=int64),
#  212: array([261, 269, 278, 271, 274, 272, 242, 276], dtype=int64),
#  213: array([ 635, 1564,  772,  781,  784,  783], dtype=int64),
#  214: array([], dtype=int64),
#  215: array([199, 218, 202, 203, 206, 194], dtype=int64),
#  216: array([1565], dtype=int64),
#  217: array([], dtype=int64),
#  218: array([199, 215, 202, 203, 206, 194], dtype=int64),
#  219: array([227, 226, 224, 222, 221, 220, 944, 228], dtype=int64),
#  220: array([227, 226, 224, 222, 221, 944, 228, 219], dtype=int64),
#  221: array([227, 226, 224, 222, 220, 944, 228, 219], dtype=int64),
#  222: array([227, 226, 224, 221, 220, 944, 228, 219], dtype=int64),
#  223: array([1518], dtype=int64),
#  224: array([227, 226, 222, 221, 220, 944, 228, 219], dtype=int64),
#  225: array([], dtype=int64),
#  226: array([227, 224, 222, 221, 220, 944, 228, 219], dtype=int64),
#  227: array([226, 224, 222, 221, 220, 944, 228, 219], dtype=int64),
#  228: array([227, 226, 224, 222, 221, 220, 944, 219], dtype=int64),
#  229: array([1928], dtype=int64),
#  230: array([ 235,  239,  258,  234, 1925,  233,  231,  243], dtype=int64),
#  231: array([ 235,  239,  258,  234, 1925,  233,  230,  243], dtype=int64),
#  232: array([237, 286, 251, 235, 238, 241, 239], dtype=int64),
#  233: array([ 235,  239,  258,  234, 1925,  231,  230,  243], dtype=int64),
#  234: array([ 235,  239,  258, 1925,  233,  231,  230,  243], dtype=int64),
#  235: array([ 988,  237,  286,  251,  238,  232,  239,  258,  234, 1925,  233,
#          231,  230,  243], dtype=int64),
#  236: array([ 252,  268,  254,  240,  256, 1458,  260,  253,  988], dtype=int64),
#  237: array([988, 286, 251, 235, 238, 232, 239], dtype=int64),
#  238: array([988, 237, 286, 251, 235, 232, 241, 239], dtype=int64),
#  239: array([ 988,  237,  286,  251,  235,  238,  232,  241,  258,  234, 1925,
#          233,  231,  230,  243], dtype=int64),
#  240: array([ 252,  268,  254,  265,  273, 1926,  256, 1458,  260,  236,  253],
#        dtype=int64),
#  241: array([738, 741, 251, 238, 232, 239, 622], dtype=int64),
#  242: array([212, 278, 277, 280, 275, 271, 274, 272, 247, 276], dtype=int64),
#  243: array([ 235,  239,  258,  234, 1925,  233,  231,  230], dtype=int64),
#  244: array([1964, 1827, 1963, 1822,   62, 1962, 1961, 1364, 1636, 1829, 1960,
#          412, 1362, 1361, 1831, 1363, 1853, 1629,  931, 1921, 1083, 1082,
#         1841, 1840, 1839, 1838, 1837,   78, 1832, 1662, 1830, 1965, 1966,
#         1826, 1836, 1835,  364, 1426], dtype=int64),
#  245: array([1183, 1177, 1178, 1929, 1182, 1181, 1180, 1179], dtype=int64),
#  246: array([1883, 1548], dtype=int64),
#  247: array([278, 277, 275, 274, 272, 242], dtype=int64),
#  248: array([], dtype=int64),
#  249: array([], dtype=int64),
#  250: array([], dtype=int64),
#  251: array([988, 237, 286, 235, 238, 232, 241, 239], dtype=int64),
#  252: array([ 254,  240,  256, 1458,  236,  253,  988], dtype=int64),
#  253: array([ 252,  268,  254,  240,  256, 1458,  260,  236,  988], dtype=int64),
#  254: array([ 252,  268,  265,  273, 1926,  240,  256, 1458,  260,  236,  253],
#        dtype=int64),
#  255: array([], dtype=int64),
#  256: array([ 252,  268,  254,  265,  273, 1926,  240, 1458,  260,  236,  253],
#        dtype=int64),
#  257: array([782, 787], dtype=int64),
#  258: array([ 235,  239,  234, 1925,  233,  231,  230,  243], dtype=int64),
#  259: array([], dtype=int64),
#  260: array([ 268,  254,  265,  273, 1926,  240,  256, 1458,  236,  253],
#        dtype=int64),
#  261: array([212, 269, 278, 271, 274, 272, 276], dtype=int64),
#  262: array([], dtype=int64),
#  263: array([842, 626], dtype=int64),
#  264: array([1321, 1340, 1674, 1320], dtype=int64),
#  265: array([ 268,  254,  273, 1926,  240,  256, 1458,  260], dtype=int64),
#  266: array([], dtype=int64),
#  267: array([], dtype=int64),
#  268: array([ 254,  265,  273, 1926,  240,  256, 1458,  260,  236,  253],
#        dtype=int64),
#  269: array([212, 261, 278, 271, 274, 272], dtype=int64),
#  270: array([281, 279, 776, 285, 284, 283], dtype=int64),
#  271: array([212, 261, 269, 278, 274, 272, 242, 276], dtype=int64),
#  272: array([212, 261, 269, 278, 277, 271, 274, 242, 247, 276], dtype=int64),
#  273: array([ 268,  254,  265, 1926,  240,  256, 1458,  260], dtype=int64),
#  274: array([212, 261, 269, 278, 277, 271, 272, 242, 247, 276], dtype=int64),
#  275: array([277, 242, 247], dtype=int64),
#  276: array([212, 261, 278, 280, 271, 274, 272, 242], dtype=int64),
#  277: array([278, 275, 274, 272, 242, 247], dtype=int64),
#  278: array([212, 261, 269, 277, 271, 274, 272, 242, 247, 276], dtype=int64),
#  279: array([270, 281, 776, 285, 284, 283], dtype=int64),
#  280: array([242, 276], dtype=int64),
#  281: array([270, 279, 776, 285, 284, 283], dtype=int64),
#  282: array([1516, 1557, 1533, 1601, 1537, 1556, 1599, 1603, 1555, 1594,   21,
#         1520, 1521, 1522, 1525, 1577, 1526, 1527, 1528, 1553, 1569, 1575,
#         1576, 1592, 1595, 1590], dtype=int64),
#  283: array([270, 281, 279, 776, 285, 284], dtype=int64),
#  284: array([270, 281, 279, 776, 285, 283], dtype=int64),
#  285: array([270, 281, 279, 776, 284, 283], dtype=int64),
#  286: array([988, 237, 251, 235, 238, 232, 239], dtype=int64),
#  287: array([351, 354, 355, 356, 342, 343, 312, 308, 303, 304, 345, 302, 301,
#         340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348, 295,
#         346, 288, 293, 327, 289, 297, 331, 333, 326], dtype=int64),
#  288: array([351, 354, 355, 356, 342, 343, 312, 308, 303, 304, 345, 302, 301,
#         340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348, 295,
#         346, 287, 293, 327, 289, 297, 331, 333, 326], dtype=int64),
#  289: array([342, 343, 312, 308, 303, 304, 345, 302, 301, 340, 305, 299, 359,
#         296, 306, 298, 347, 393, 317, 344, 348, 295, 346, 287, 288, 293,
#         327, 297, 331, 333, 326, 335], dtype=int64),
#  290: array([349, 292, 350, 291, 312, 392, 308, 303, 304, 302, 301, 340, 299,
#         359, 296, 298, 347, 317, 348, 295, 346, 293], dtype=int64),
#  291: array([349, 292, 350, 290, 312, 392, 308, 303, 304, 302, 301, 340, 299,
#         359, 296, 298, 347, 393, 317, 348, 295, 346, 293], dtype=int64),
#  292: array([349, 350, 291, 290, 312, 392, 308, 303, 304, 302, 301, 340, 299,
#         359, 296, 298, 347, 393, 317, 348, 295, 346, 293], dtype=int64),
#  293: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344,
#         348, 295, 346, 287, 288, 289, 297, 331, 333], dtype=int64),
#  294: array([ 111,  103, 1284,   97,   98,  104,  113,  739], dtype=int64),
#  295: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344,
#         348, 346, 287, 288, 293, 289, 297], dtype=int64),
#  296: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 299, 359, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  297: array([308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296, 306, 298,
#         347, 393, 317, 344, 348, 295, 346, 287, 288, 293, 327, 289, 331,
#         333, 326, 335], dtype=int64),
#  298: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 299, 359, 296, 306, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  299: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 359, 296, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  300: array([ 769, 1896,  314], dtype=int64),
#  301: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  302: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  303: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 304, 345, 302,
#         301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  304: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 345, 302,
#         301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348,
#         295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  305: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 319, 342, 343, 325,
#         324, 323, 350, 318, 312, 310, 358, 307, 908, 311, 308, 303, 304,
#         345, 302, 301, 340, 299, 359, 296, 306, 298, 347, 393, 317, 344,
#         348, 295, 346, 287, 288, 293, 327, 289, 297, 331, 333], dtype=int64),
#  306: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 319, 342, 343, 325,
#         324, 323, 350, 318, 312, 310, 358, 307, 908, 311, 308, 303, 304,
#         345, 302, 301, 340, 305, 299, 359, 296, 298, 347, 393, 317, 344,
#         348, 295, 346, 287, 288, 293, 327, 289, 297, 331, 333], dtype=int64),
#  307: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 318, 310, 358, 908, 311, 305, 306, 344, 327], dtype=int64),
#  308: array([371, 372, 373, 351, 349, 342, 343, 292, 350, 291, 290, 312, 392,
#         303, 304, 345, 302, 301, 340, 305, 299, 359, 296, 306, 298, 347,
#         393, 317, 344, 348, 295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  309: array([1803, 1814, 1817,  315], dtype=int64),
#  310: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 318, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  311: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 318, 310, 358, 307, 908, 305, 306, 344, 327], dtype=int64),
#  312: array([366, 383, 384, 361, 371, 372, 373, 351, 354, 355, 356, 349, 342,
#         343, 292, 350, 291, 290, 392, 308, 303, 304, 345, 302, 301, 340,
#         305, 299, 359, 296, 306, 298, 347, 393, 317, 344, 348, 295, 346,
#         287, 288, 293, 289], dtype=int64),
#  313: array([338], dtype=int64),
#  314: array([ 769, 1896,  300], dtype=int64),
#  315: array([1803, 1814, 1817,  309], dtype=int64),
#  316: array([], dtype=int64),
#  317: array([371, 372, 373, 351, 349, 342, 343, 292, 350, 291, 290, 312, 392,
#         308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296, 306, 298,
#         347, 393, 344, 348, 295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  318: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 310, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  319: array([361, 371, 372, 373, 354, 355, 356, 342, 343, 325, 324, 323, 320,
#         318, 310, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  320: array([361, 354, 355, 356, 319, 342, 343, 325, 324, 323, 318, 310, 358,
#         307, 908, 311, 327], dtype=int64),
#  321: array([1927], dtype=int64),
#  322: array([368, 341, 375, 363], dtype=int64),
#  323: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 320,
#         318, 310, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  324: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 323, 320,
#         318, 310, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  325: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 324, 323, 320,
#         318, 310, 358, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  326: array([287, 288, 327, 289, 297, 331, 333, 335], dtype=int64),
#  327: array([319, 342, 343, 325, 324, 323, 320, 318, 310, 358, 307, 908, 311,
#         345, 305, 359, 306, 393, 344, 287, 288, 289, 297, 331, 333, 326,
#         335], dtype=int64),
#  328: array([1888, 1680, 1355, 1655, 1656, 1661, 1681, 1864,  625,   66, 1676,
#         1900, 1913, 1914,  620, 1669, 1471, 1663, 1668, 1667,  387, 1825,
#          330, 1905], dtype=int64),
#  329: array([360], dtype=int64),
#  330: array([1650, 1888, 1680, 1355, 1655, 1656, 1661, 1681, 1864, 1911, 1909,
#          625,  780,   66, 1676, 1908, 1906, 1900, 1913, 1914, 1884,  328,
#          620, 1669, 1471, 1663, 1668, 1667,  387, 1905], dtype=int64),
#  331: array([342, 343, 345, 340, 305, 359, 306, 393, 344, 287, 288, 293, 327,
#         289, 297, 333, 326, 335], dtype=int64),
#  332: array([134, 135, 337, 365], dtype=int64),
#  333: array([342, 343, 345, 340, 305, 359, 306, 393, 344, 287, 288, 293, 327,
#         289, 297, 331, 326, 335], dtype=int64),
#  334: array([], dtype=int64),
#  335: array([327, 289, 297, 331, 333, 326], dtype=int64),
#  336: array([1930], dtype=int64),
#  337: array([332, 134, 135, 365], dtype=int64),
#  338: array([313], dtype=int64),
#  339: array([1015, 1100, 1044, 1045, 1948, 1030, 1036, 1080, 1035, 1020, 1038,
#           11, 1029, 1285, 1063, 1064, 1089, 1025, 1065, 1112, 1059, 1037,
#         1109, 1108, 1006, 1478,  210, 1068, 1090, 1113,   69, 1094,   67,
#         1481, 1111, 1024, 1115, 1027, 1461, 1119, 1060, 1069, 1062, 1102,
#         1058, 1104, 1105, 1106, 1107, 1110], dtype=int64),
#  340: array([371, 372, 373, 351, 349, 342, 343, 292, 350, 291, 290, 312, 392,
#         308, 303, 304, 345, 302, 301, 305, 299, 359, 296, 306, 298, 347,
#         393, 317, 344, 348, 295, 346, 287, 288, 293, 289, 297, 331, 333],
#        dtype=int64),
#  341: array([ 368,  322,  375,  363, 1918], dtype=int64),
#  342: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 319, 343, 325, 324,
#         323, 350, 320, 318, 312, 310, 358, 307, 908, 311, 308, 303, 304,
#         345, 302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317,
#         344, 348, 295, 346, 287, 288, 293, 327, 289, 331, 333], dtype=int64),
#  343: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 319, 342, 325, 324,
#         323, 350, 320, 318, 312, 310, 358, 307, 908, 311, 308, 303, 304,
#         345, 302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317,
#         344, 348, 295, 346, 287, 288, 293, 327, 289, 331, 333], dtype=int64),
#  344: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 319, 342, 343, 325,
#         324, 323, 350, 318, 312, 310, 358, 307, 908, 311, 308, 303, 304,
#         345, 302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317,
#         348, 295, 346, 287, 288, 293, 327, 289, 297, 331, 333], dtype=int64),
#  345: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 342, 343, 350, 312,
#         308, 303, 304, 302, 301, 340, 305, 299, 359, 296, 306, 298, 347,
#         393, 317, 344, 348, 295, 346, 287, 288, 293, 327, 289, 297, 331,
#         333], dtype=int64),
#  346: array([349, 342, 343, 292, 350, 291, 290, 312, 392, 308, 303, 304, 345,
#         302, 301, 340, 305, 299, 359, 296, 306, 298, 347, 393, 317, 344,
#         348, 295, 287, 288, 293, 289, 297], dtype=int64),
#  347: array([371, 372, 373, 351, 349, 342, 343, 292, 350, 291, 290, 312, 392,
#         308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296, 306, 298,
#         393, 317, 344, 348, 295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  348: array([371, 372, 373, 351, 349, 342, 343, 292, 350, 291, 290, 312, 392,
#         308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296, 306, 298,
#         347, 393, 317, 344, 295, 346, 287, 288, 293, 289, 297], dtype=int64),
#  349: array([366, 383, 384, 371, 372, 373, 351, 342, 343, 292, 350, 291, 290,
#         312, 392, 308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296,
#         306, 298, 347, 393, 317, 344, 348, 295, 346, 293], dtype=int64),
#  350: array([366, 383, 384, 371, 372, 373, 351, 349, 342, 343, 292, 291, 290,
#         312, 392, 308, 303, 304, 345, 302, 301, 340, 305, 299, 359, 296,
#         306, 298, 347, 393, 317, 344, 348, 295, 346, 293], dtype=int64),
#  351: array([366, 383, 384, 361, 371, 372, 373, 354, 355, 356, 349, 342, 343,
#         350, 312, 308, 345, 340, 305, 359, 306, 347, 393, 317, 344, 348,
#         287, 288], dtype=int64),
#  352: array([ 375, 1918,  353,  361,  371,  372,  373,  354,  355,  356],
#        dtype=int64),
#  353: array([ 375, 1918,  352,  361,  371,  372,  373,  354,  355,  356],
#        dtype=int64),
#  354: array([1918,  352,  353,  361,  371,  372,  373,  351,  355,  356,  319,
#          342,  343,  325,  324,  323,  320,  318,  312,  310,  358,  307,
#          908,  311,  345,  305,  359,  306,  393,  344,  287,  288],
#        dtype=int64),
#  355: array([1918,  352,  353,  361,  371,  372,  373,  351,  354,  356,  319,
#          342,  343,  325,  324,  323,  320,  318,  312,  310,  358,  307,
#          908,  311,  345,  305,  359,  306,  393,  344,  287,  288],
#        dtype=int64),
#  356: array([1918,  352,  353,  361,  371,  372,  373,  351,  354,  355,  319,
#          342,  343,  325,  324,  323,  320,  318,  312,  310,  358,  307,
#          908,  311,  345,  305,  359,  306,  393,  344,  287,  288],
#        dtype=int64),
#  357: array([], dtype=int64),
#  358: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 318, 310, 307, 908, 311, 305, 306, 344, 327], dtype=int64),
#  359: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 342, 343, 292, 350,
#         291, 290, 312, 392, 308, 303, 304, 345, 302, 301, 340, 305, 299,
#         296, 306, 298, 347, 393, 317, 344, 348, 295, 346, 287, 288, 293,
#         327, 289, 297, 331, 333], dtype=int64),
#  360: array([329, 368], dtype=int64),
#  361: array([1918,  352,  353,  366,  383,  384,  371,  372,  373,  351,  354,
#          355,  356,  319,  342,  343,  325,  324,  323,  320,  318,  312,
#          310,  358,  307,  908,  311,  345,  305,  359,  306,  393,  344],
#        dtype=int64),
#  362: array([571, 377, 379, 378, 380, 808], dtype=int64),
#  363: array([ 341,  322,  375, 1918], dtype=int64),
#  364: array([1964, 1963, 1805, 1962, 1961, 1364, 1807, 1636, 1829, 1960,  412,
#         1362, 1361, 1363, 1853, 1806, 1629,  931, 1782,  244, 1795, 1083,
#         1082, 1841, 1840, 1796, 1839, 1838, 1837, 1833,   78, 1832, 1662,
#         1830, 1804, 1965, 1966, 1809, 1835, 1808, 1915, 1815, 1813, 1816,
#         1810, 1638, 1811, 1426, 1347, 1842, 1645, 1640, 1660, 1672, 1671,
#         1670, 1665, 1664, 1657, 1648, 1649, 1641, 1647, 1659, 1654, 1653,
#         1651, 1675, 1677, 1678, 1683, 1685, 1812], dtype=int64),
#  365: array([332, 134, 135, 337], dtype=int64),
#  366: array([383, 384, 361, 371, 372, 373, 351, 349, 350, 312], dtype=int64),
#  367: array([], dtype=int64),
#  368: array([360, 341, 322, 375], dtype=int64),
#  369: array([], dtype=int64),
#  370: array([], dtype=int64),
#  371: array([352, 353, 366, 383, 384, 361, 372, 373, 351, 354, 355, 356, 349,
#         319, 342, 343, 325, 324, 323, 350, 318, 312, 310, 358, 307, 908,
#         311, 308, 345, 340, 305, 359, 306, 347, 393, 317, 344, 348],
#        dtype=int64),
#  372: array([352, 353, 366, 383, 384, 361, 371, 373, 351, 354, 355, 356, 349,
#         319, 342, 343, 325, 324, 323, 350, 318, 312, 310, 358, 307, 908,
#         311, 308, 345, 340, 305, 359, 306, 347, 393, 317, 344, 348],
#        dtype=int64),
#  373: array([352, 353, 366, 383, 384, 361, 371, 372, 351, 354, 355, 356, 349,
#         319, 342, 343, 325, 324, 323, 350, 318, 312, 310, 358, 307, 908,
#         311, 308, 345, 340, 305, 359, 306, 347, 393, 317, 344, 348],
#        dtype=int64),
#  374: array([], dtype=int64),
#  375: array([ 368,  341,  322,  363, 1918,  352,  353], dtype=int64),
#  376: array([618, 377, 379, 378], dtype=int64),
#  377: array([571, 618, 379, 378, 376, 380, 808, 362], dtype=int64),
#  378: array([571, 618, 377, 379, 376, 380, 808, 362], dtype=int64),
#  379: array([571, 618, 377, 378, 376, 380, 808, 362], dtype=int64),
#  380: array([571, 377, 379, 378, 808, 362], dtype=int64),
#  381: array([], dtype=int64),
#  382: array([385, 388], dtype=int64),
#  383: array([366, 384, 361, 371, 372, 373, 351, 349, 350, 312], dtype=int64),
#  384: array([366, 383, 361, 371, 372, 373, 351, 349, 350, 312], dtype=int64),
#  385: array([388, 382], dtype=int64),
#  386: array([], dtype=int64),
#  387: array([1877, 1878, 1917, 1810, 1811, 1347, 1640, 1660, 1672, 1671, 1670,
#         1665, 1664, 1657, 1648, 1649, 1641, 1647, 1659, 1654, 1653, 1651,
#         1675, 1677, 1678, 1683, 1685, 1812, 1679, 1899, 1902, 1650, 1888,
#         1844, 1845, 1846, 1847, 1901, 1680, 1355, 1655, 1656, 1661, 1681,
#         1864, 1911, 1909,  625,  780, 1907,   66, 1676, 1908, 1906, 1900,
#         1848, 1913, 1914, 1884, 1857, 1849, 1873, 1881, 1868,  328,  620,
#         1904, 1669, 1663, 1668, 1667,  330], dtype=int64),
#  388: array([385, 382], dtype=int64),
#  389: array([390], dtype=int64),
#  390: array([389], dtype=int64),
#  391: array([  93, 1608,   81,   80,  138,  137,  163,  122,  121,  106,   87,
#           91], dtype=int64),
#  392: array([349, 292, 350, 291, 290, 312, 308, 303, 304, 302, 301, 340, 299,
#         359, 296, 298, 347, 393, 317, 348, 295, 346, 293], dtype=int64),
#  393: array([361, 371, 372, 373, 351, 354, 355, 356, 349, 342, 343, 292, 350,
#         291, 312, 392, 308, 303, 304, 345, 302, 301, 340, 305, 299, 359,
#         296, 306, 298, 347, 317, 344, 348, 295, 346, 287, 288, 293, 327,
#         289, 297, 331, 333], dtype=int64),
#  394: array([57], dtype=int64),
#  395: array([424, 416], dtype=int64),
#  396: array([], dtype=int64),
#  397: array([399, 403, 398, 404], dtype=int64),
#  398: array([399, 403, 397, 404], dtype=int64),
#  399: array([403, 397, 398, 404], dtype=int64),
#  400: array([], dtype=int64),
#  401: array([], dtype=int64),
#  402: array([ 603, 1469,  407,  408], dtype=int64),
#  403: array([399, 397, 398, 404], dtype=int64),
#  404: array([399, 403, 397, 398], dtype=int64),
#  405: array([], dtype=int64),
#  406: array([], dtype=int64),
#  407: array([ 603, 1469,  402,  408], dtype=int64),
#  408: array([ 603, 1469,  402,  407], dtype=int64),
#  409: array([ 410,  603, 1469], dtype=int64),
#  410: array([ 409,  603, 1469], dtype=int64),
#  411: array([], dtype=int64),
#  412: array([1964, 1963, 1822, 1962, 1961, 1364, 1636, 1960, 1362, 1361, 1363,
#         1853, 1637, 1629,  931,  244, 1921, 1083, 1082, 1841, 1840, 1839,
#         1838, 1837,   78, 1832, 1662, 1965, 1966, 1835,  364, 1638, 1426,
#         1645], dtype=int64),
#  413: array([415, 418, 419, 417], dtype=int64),
#  414: array([ 447,  463,  488,  440,  456,  458,  492,  446,  811,  438,  476,
#          457,  455, 1652,  454,  453,  448,  486], dtype=int64),
#  415: array([418, 419, 417, 413], dtype=int64),
#  416: array([395, 424], dtype=int64),
#  417: array([415, 418, 419, 413], dtype=int64),
#  418: array([415, 419, 417, 413], dtype=int64),
#  419: array([415, 418, 417, 413], dtype=int64),
#  420: array([], dtype=int64),
#  421: array([422], dtype=int64),
#  422: array([421], dtype=int64),
#  423: array([], dtype=int64),
#  424: array([395, 416], dtype=int64),
#  425: array([], dtype=int64),
#  426: array([], dtype=int64),
#  427: array([ 901,  541,  902,  578, 1937, 1936,  549], dtype=int64),
#  428: array([], dtype=int64),
#  429: array([], dtype=int64),
#  430: array([1722, 1710, 1137, 1711, 1719, 1720, 1620, 1712, 1713, 1714, 1715,
#         1716, 1717, 1718, 1708, 1721, 1752, 1709, 1726, 1728, 1729, 1730,
#         1707, 1552, 1754, 1723, 1740, 1621, 1756, 1732, 1161, 1743, 1757,
#         1733, 1734, 1724,  639, 1742, 1705, 1744, 1706, 1745, 1735, 1736,
#         1737, 1738, 1739, 1746, 1748, 1750, 1758], dtype=int64),
#  431: array([1136], dtype=int64),
#  432: array([1923], dtype=int64),
#  433: array([477, 481, 482, 449, 448, 489], dtype=int64),
#  434: array([450], dtype=int64),
#  435: array([467, 468], dtype=int64),
#  436: array([452, 440, 456, 458, 492, 439, 446, 466, 450, 487, 462, 461, 460,
#         442, 459, 437, 491, 451, 486], dtype=int64),
#  437: array([439, 446, 466, 450, 487, 462, 461, 460, 442, 459, 436, 448, 491,
#         451, 486], dtype=int64),
#  438: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  811,  476,
#          457,  455, 1652,  454,  453,  448,  486], dtype=int64),
#  439: array([452, 463, 488, 440, 456, 458, 492, 446, 466, 450, 487, 462, 461,
#         460, 442, 459, 437, 436, 491, 451, 486], dtype=int64),
#  440: array([ 452,  447,  463,  488,  456,  458,  492,  439,  446,  414,  466,
#          462,  461,  460,  442,  811,  438,  476,  457,  455, 1652,  436,
#          454,  453,  486], dtype=int64),
#  441: array([445], dtype=int64),
#  442: array([ 452,  447,  463,  488,  440,  456,  458,  492,  439,  446,  466,
#          487,  462,  461,  460,  459,  476,  437, 1652,  436,  453,  448,
#          491,  451,  486], dtype=int64),
#  443: array([1226, 1192, 1219, 1209, 1208, 1194, 1163, 1162, 1203, 1197, 1196,
#         1195, 1193, 1189, 1190, 1191, 1213, 1164, 1165, 1166, 1167, 1225,
#         1150], dtype=int64),
#  444: array([], dtype=int64),
#  445: array([478, 485, 441], dtype=int64),
#  446: array([ 452,  447,  463,  488,  440,  456,  458,  492,  439,  414,  466,
#          462,  461,  460,  442,  459,  811,  438,  476,  457,  455,  437,
#         1652,  436,  454,  453,  448,  451,  486], dtype=int64),
#  447: array([ 452,  463,  488,  440,  456,  458,  492,  446,  414,  442,  811,
#          438,  476,  457,  455, 1652,  454,  453,  486], dtype=int64),
#  448: array([ 446,  414,  442,  459,  811,  438,  477,  476,  457,  437, 1652,
#          481,  454,  453,  433,  482,  449,  489,  486], dtype=int64),
#  449: array([477, 481, 433, 482, 448, 489], dtype=int64),
#  450: array([452, 434, 439, 466, 487, 462, 461, 460, 459, 437, 436, 491, 451],
#        dtype=int64),
#  451: array([452, 439, 446, 466, 450, 487, 462, 461, 460, 442, 459, 437, 436,
#         491, 486], dtype=int64),
#  452: array([447, 463, 488, 440, 456, 458, 492, 439, 446, 466, 450, 462, 461,
#         460, 442, 436, 451, 486], dtype=int64),
#  453: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  442,  811,
#          438,  476,  457,  455, 1652,  454,  448,  486], dtype=int64),
#  454: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  811,  438,
#          476,  457,  455, 1652,  453,  448,  486], dtype=int64),
#  455: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  811,  438,
#          476,  457, 1652,  454,  453,  486], dtype=int64),
#  456: array([ 452,  447,  463,  488,  440,  458,  492,  439,  446,  414,  466,
#          462,  461,  460,  442,  811,  438,  476,  457,  455, 1652,  436,
#          454,  453,  486], dtype=int64),
#  457: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  811,  438,
#          476,  455, 1652,  454,  453,  448,  486], dtype=int64),
#  458: array([ 452,  447,  463,  488,  440,  456,  492,  439,  446,  414,  466,
#          462,  461,  460,  442,  811,  438,  476,  457,  455, 1652,  436,
#          454,  453,  486], dtype=int64),
#  459: array([439, 446, 466, 450, 487, 462, 461, 460, 442, 437, 436, 448, 491,
#         451, 486], dtype=int64),
#  460: array([452, 440, 456, 458, 492, 439, 446, 466, 450, 487, 462, 461, 442,
#         459, 437, 436, 491, 451, 486], dtype=int64),
#  461: array([452, 440, 456, 458, 492, 439, 446, 466, 450, 487, 462, 460, 442,
#         459, 437, 436, 491, 451, 486], dtype=int64),
#  462: array([452, 440, 456, 458, 492, 439, 446, 466, 450, 487, 461, 460, 442,
#         459, 437, 436, 491, 451, 486], dtype=int64),
#  463: array([ 452,  447,  488,  440,  456,  458,  492,  439,  446,  414,  442,
#          811,  438,  476,  457,  455, 1652,  454,  453,  486], dtype=int64),
#  464: array([], dtype=int64),
#  465: array([], dtype=int64),
#  466: array([452, 440, 456, 458, 492, 439, 446, 450, 487, 462, 461, 460, 442,
#         459, 437, 436, 491, 451, 486], dtype=int64),
#  467: array([468, 435], dtype=int64),
#  468: array([467, 435], dtype=int64),
#  469: array([100, 471, 470], dtype=int64),
#  470: array([100, 469, 471], dtype=int64),
#  471: array([100, 469, 470], dtype=int64),
#  472: array([474, 473], dtype=int64),
#  473: array([474, 472], dtype=int64),
#  474: array([472, 473], dtype=int64),
#  475: array([], dtype=int64),
#  476: array([ 447,  463,  488,  440,  456,  458,  492,  446,  414,  442,  811,
#          438,  457,  455, 1652,  454,  453,  448,  486], dtype=int64),
#  477: array([481, 433, 482, 449, 448, 489], dtype=int64),
#  478: array([485, 445], dtype=int64),
#  479: array([], dtype=int64),
#  480: array([], dtype=int64),
#  481: array([477, 433, 482, 449, 448, 489], dtype=int64),
#  482: array([477, 481, 433, 449, 448, 489], dtype=int64),
#  483: array([], dtype=int64),
#  484: array([1443], dtype=int64),
#  485: array([478, 445], dtype=int64),
#  486: array([ 452,  447,  463,  488,  440,  456,  458,  492,  439,  446,  414,
#          466,  462,  461,  460,  442,  459,  811,  438,  476,  457,  455,
#          437, 1652,  436,  454,  453,  448,  451], dtype=int64),
#  487: array([439, 466, 450, 462, 461, 460, 442, 459, 437, 436, 491, 451],
#        dtype=int64),
#  488: array([ 452,  447,  463,  440,  456,  458,  492,  439,  446,  414,  442,
#          811,  438,  476,  457,  455, 1652,  454,  453,  486], dtype=int64),
#  489: array([477, 481, 433, 482, 449, 448], dtype=int64),
#  490: array([], dtype=int64),
#  491: array([439, 466, 450, 487, 462, 461, 460, 442, 459, 437, 436, 451],
#        dtype=int64),
#  492: array([ 452,  447,  463,  488,  440,  456,  458,  439,  446,  414,  466,
#          462,  461,  460,  442,  811,  438,  476,  457,  455, 1652,  436,
#          454,  453,  486], dtype=int64),
#  493: array([1440], dtype=int64),
#  494: array([496], dtype=int64),
#  495: array([], dtype=int64),
#  496: array([494], dtype=int64),
#  497: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
#         524, 520, 526, 527, 523, 711, 509, 529, 534, 535, 536, 537, 554,
#         564, 565, 572, 573, 580, 581, 591, 595, 596, 556, 498, 532, 533,
#         501, 502, 503, 504, 505, 506, 507, 799, 797, 508], dtype=int64),
#  498: array([ 542,  669,  543,  711, 1934,  509,  556,  532,  533,  497,  501,
#          502,  503,  504,  505,  506,  507,  799,  797,  508], dtype=int64),
#  499: array([544, 900], dtype=int64),
#  500: array([545], dtype=int64),
#  501: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
#         524, 520, 526, 527, 523, 711, 509, 529, 534, 535, 536, 537, 554,
#         564, 565, 572, 573, 580, 581, 591, 595, 596, 556, 498, 532, 533,
#         497, 502, 503, 504, 505, 506, 507, 799, 797, 508], dtype=int64),
#  502: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
#         524, 520, 526, 527, 523, 711, 509, 529, 534, 535, 536, 537, 554,
#         564, 565, 572, 573, 580, 581, 591, 595, 596, 556, 498, 532, 533,
#         497, 501, 503, 504, 505, 506, 507, 799, 797, 508], dtype=int64),
#  503: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
#         524, 520, 526, 527, 523, 711, 509, 529, 534, 535, 536, 537, 554,
#         564, 565, 572, 573, 580, 581, 591, 595, 596, 556, 498, 532, 533,
#         497, 501, 502, 504, 505, 506, 507, 799, 797, 508], dtype=int64),
#  504: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
#         524, 520, 526, 527, 523, 711, 509, 529, 534, 535, 536, 537, 554,
#         564, 565, 572, 573, 580, 581, 591, 595, 596, 556, 498, 532, 533,
#         497, 501, 502, 503, 505, 506, 507, 799, 797, 508], dtype=int64),
#  505: array([559, 552, 553, 918, 555, 510, 513, 514, 515, 522, 525, 521, 528,
# ...
#        dtype=int64),
#  821: array([], dtype=int64),
#  822: array([ 802,  833,  806,  807,  830,  832, 1325,  814], dtype=int64),
#  823: array([], dtype=int64),
#  824: array([840, 834, 802, 833, 829, 175, 887, 806, 807, 830, 832, 836, 841,
#         827], dtype=int64),
#  825: array([], dtype=int64),
#  826: array([ 836,  841,  835, 1584,  827], dtype=int64),
#  827: array([ 824,  829,  175,  887,  806,  807,  830,  832,  836,  841,  835,
#         1584,  826], dtype=int64),
#  828: array([108, 111, 103], dtype=int64),
#  829: array([840, 834, 802, 833, 824, 175, 887, 806, 807, 830, 832, 836, 841,
#         827], dtype=int64),
#  830: array([ 840,  834,  802,  833,  824,  829,  175,  887,  806,  807,  832,
#         1325,  822,  827], dtype=int64),
#  831: array([905, 838, 836, 841], dtype=int64),
#  832: array([ 840,  834,  802,  833,  824,  829,  175,  887,  806,  807,  830,
#         1325,  822,  827], dtype=int64),
#  833: array([840, 834, 802, 824, 829, 175, 887, 806, 807, 830, 832, 822],
#        dtype=int64),
#  834: array([840, 802, 833, 824, 829, 175, 887, 806, 807, 830, 832], dtype=int64),
#  835: array([ 836,  841, 1584,  827,  826], dtype=int64),
#  836: array([ 831,  824,  829,  175,  887,  841,  835, 1584,  827,  826],
#        dtype=int64),
#  837: array([839], dtype=int64),
#  838: array([905, 831], dtype=int64),
#  839: array([837], dtype=int64),
#  840: array([834, 802, 833, 824, 829, 175, 887, 806, 807, 830, 832], dtype=int64),
#  841: array([ 831,  824,  829,  175,  887,  836,  835, 1584,  827,  826],
#        dtype=int64),
#  842: array([263, 626], dtype=int64),
#  843: array([803, 844, 845, 846, 847, 848, 810, 812], dtype=int64),
#  844: array([803, 843, 845, 846, 847, 848, 810, 812], dtype=int64),
#  845: array([803, 843, 844, 846, 847, 848, 804, 805, 809, 810, 812], dtype=int64),
#  846: array([803, 843, 844, 845, 847, 848, 810, 812], dtype=int64),
#  847: array([803, 843, 844, 845, 846, 848, 810, 812], dtype=int64),
#  848: array([803, 843, 844, 845, 846, 847, 810, 812], dtype=int64),
#  849: array([], dtype=int64),
#  850: array([   5,  730, 1274,   38,  800,  688,  706, 1943,  668,  727],
#        dtype=int64),
#  851: array([922, 909, 853, 884, 885, 546], dtype=int64),
#  852: array([], dtype=int64),
#  853: array([922, 909, 851, 884, 885, 546], dtype=int64),
#  854: array([ 610,  567,  566,  519,  675,  517,  518,  684,  570,  600,  674,
#          689,  690,  695,  875,  876, 1582,  574,  658,  729,  531,  575,
#          576,  579,  582,  583,  587,  597,  678, 1932,  877,  696, 1329],
#        dtype=int64),
#  855: array([], dtype=int64),
#  856: array([], dtype=int64),
#  857: array([], dtype=int64),
#  858: array([867, 868, 870, 913, 866], dtype=int64),
#  859: array([], dtype=int64),
#  860: array([862, 861, 863, 869, 871], dtype=int64),
#  861: array([862, 860, 869, 871], dtype=int64),
#  862: array([860, 861, 869, 871], dtype=int64),
#  863: array([860, 869], dtype=int64),
#  864: array([1030, 1036, 1080, 1035, 1038,   11, 1029, 1285, 1109, 1108, 1478,
#         1034,  865, 1118, 1018, 1019, 1103, 1951], dtype=int64),
#  865: array([1030, 1036, 1080, 1035, 1038,   11, 1029, 1285, 1109, 1108,  864,
#         1478, 1034, 1118, 1018, 1019, 1103, 1951], dtype=int64),
#  866: array([867, 868, 870, 858, 913], dtype=int64),
#  867: array([868, 870, 858, 913, 866], dtype=int64),
#  868: array([867, 870, 858, 913, 866], dtype=int64),
#  869: array([862, 860, 861, 863, 871], dtype=int64),
#  870: array([867, 868, 858, 913, 866], dtype=int64),
#  871: array([862, 860, 861, 869], dtype=int64),
#  872: array([920, 917, 911, 903], dtype=int64),
#  873: array([], dtype=int64),
#  874: array([], dtype=int64),
#  875: array([ 610,  567,  566,  519,  675,  517,  518,  684,  570,  600,  674,
#          689,  690,  695,  854,  876, 1582,  574,  658,  729,  531,  575,
#          576,  579,  582,  583,  587,  597,  678, 1932,  877,  696, 1329],
#        dtype=int64),
#  876: array([ 610,  567,  566,  519,  675,  517,  518,  684,  570,  600,  674,
#          689,  690,  695,  854,  875, 1582,  574,  658,  729,  531,  575,
#          576,  579,  582,  583,  587,  597,  678, 1932,  877,  696, 1329],
#        dtype=int64),
#  877: array([ 567,  566,  519,  675,  517,  518,  684,  570,  600,  674,  689,
#          690,  695,  854,  875,  876, 1582,  574,  658,  530,  677,  681,
#          683,  693,  914,  729,  531,  575,  576,  579,  582,  583,  587,
#          597,  678, 1932,  696, 1329,  611,  612,  609,  605,  601,  604,
#          613,  614], dtype=int64),
#  878: array([721, 724, 726, 686, 728], dtype=int64),
#  879: array([633, 634, 994, 643, 641, 995, 993, 657, 642], dtype=int64),
#  880: array([], dtype=int64),
#  881: array([], dtype=int64),
#  882: array([916, 891, 889], dtype=int64),
#  883: array([], dtype=int64),
#  884: array([922, 909, 853, 851, 885, 546], dtype=int64),
#  885: array([922, 909, 853, 851, 884, 546], dtype=int64),
#  886: array([], dtype=int64),
#  887: array([840, 834, 802, 833, 824, 829, 175, 806, 807, 830, 832, 836, 841,
#         827], dtype=int64),
#  888: array([], dtype=int64),
#  889: array([916, 891, 882], dtype=int64),
#  890: array([], dtype=int64),
#  891: array([916, 882, 889], dtype=int64),
#  892: array([698, 699, 722, 723], dtype=int64),
#  893: array([], dtype=int64),
#  894: array([], dtype=int64),
#  895: array([], dtype=int64),
#  896: array([], dtype=int64),
#  897: array([1509, 1507], dtype=int64),
#  898: array([ 704,  588,  589,  590, 1933,  594,  599,  557,  563,  729,  568,
#          569, 1329,  110, 1684, 1942], dtype=int64),
#  899: array([], dtype=int64),
#  900: array([499, 544, 799, 797], dtype=int64),
#  901: array([ 796,  550, 1939,  427, 1952,  541,  902, 1941,  578, 1937, 1936,
#          115,  549], dtype=int64),
#  902: array([ 796,  550, 1939,  427,  901, 1952,  541, 1941,  578, 1937, 1936,
#          115,  549,  545], dtype=int64),
#  903: array([872, 920, 917, 911], dtype=int64),
#  904: array([], dtype=int64),
#  905: array([838, 831], dtype=int64),
#  906: array([687, 679, 707, 794, 691,  99, 910, 692, 697, 701, 670, 715, 671,
#         672, 675, 751, 685, 676, 680, 530, 677, 681, 683, 693, 914],
#        dtype=int64),
#  907: array([], dtype=int64),
#  908: array([361, 371, 372, 373, 354, 355, 356, 319, 342, 343, 325, 324, 323,
#         320, 318, 310, 358, 307, 311, 305, 306, 344, 327], dtype=int64),
#  909: array([922, 853, 851, 884, 885, 546], dtype=int64),
#  910: array([687, 679, 707, 794, 691,  99, 906, 692, 697, 701, 670, 715, 671,
#         672, 675, 751, 685, 676, 680, 530, 677, 681, 683, 693, 914],
#        dtype=int64),
#  911: array([872, 920, 917, 903], dtype=int64),
#  912: array([], dtype=int64),
#  913: array([867, 868, 870, 858, 866], dtype=int64),
#  914: array([687, 679, 707, 794, 691,  99, 910, 906, 692, 697, 701, 670, 715,
#         671, 672, 675, 751, 685, 676, 680, 530, 677, 681, 683, 693, 531,
#         575, 576, 579, 582, 583, 587, 597, 877, 611, 612, 609, 605, 601,
#         604], dtype=int64),
#  915: array([ 586, 1931,  548,  538,  539,  540, 1940], dtype=int64),
#  916: array([891, 882, 889], dtype=int64),
#  917: array([872, 920, 911, 903], dtype=int64),
#  918: array([599, 557, 563, 558, 561, 559, 552, 553, 555, 510, 513, 514, 515,
#         522, 525, 521, 528, 524, 520, 526, 527, 523, 110, 529, 534, 535,
#         536, 537, 554, 564, 565, 572, 573, 580, 581, 591, 595, 596, 556,
#         532, 533, 497, 501, 502, 503, 504, 505, 506, 507, 508], dtype=int64),
#  919: array([], dtype=int64),
#  920: array([872, 917, 911, 903], dtype=int64),
#  921: array([], dtype=int64),
#  922: array([909, 853, 851, 884, 885, 546], dtype=int64),
#  923: array([927, 928, 937, 938, 972, 636, 637, 638, 942, 939, 940, 943, 985,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  924: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 932, 925, 933, 926, 952, 991, 929, 628], dtype=int64),
#  925: array([636, 637, 638, 923, 942, 939, 940, 943, 985, 934, 924, 932, 933,
#         926, 952, 991, 929, 628], dtype=int64),
#  926: array([636, 637, 638, 923, 942, 939, 940, 943, 985, 934, 924, 932, 925,
#         933, 952, 991, 929, 628], dtype=int64),
#  927: array([930, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 933], dtype=int64),
#  928: array([930, 927, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 933], dtype=int64),
#  929: array([934, 924, 932, 925, 933, 926, 959, 974, 955, 954, 952, 951, 950,
#         949, 948, 947, 946, 945, 991, 628, 984, 966, 987, 967, 986],
#        dtype=int64),
#  930: array([927, 928, 937, 938, 972], dtype=int64),
#  931: array([1964, 1827, 1963, 1822,   62, 1962, 1961, 1364, 1636, 1829, 1960,
#          412, 1362, 1361, 1831, 1363, 1853, 1629,  244, 1921, 1083, 1082,
#         1841, 1840, 1839, 1838, 1837,   78, 1832, 1662, 1830, 1965, 1966,
#         1826, 1836, 1835,  364, 1426], dtype=int64),
#  932: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 925, 933, 926, 952, 991, 929, 628], dtype=int64),
#  933: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 925, 926, 952, 991, 929, 628], dtype=int64),
#  934: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 924, 932, 925, 933, 926, 952, 991, 929, 628], dtype=int64),
#  935: array([], dtype=int64),
#  936: array([963, 962, 979, 961, 977, 964, 976, 992, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  937: array([930, 927, 928, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 933], dtype=int64),
#  938: array([930, 927, 928, 937, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 933], dtype=int64),
#  939: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 940, 943, 985,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  940: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 943, 985,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  941: array([1002, 1003, 1000, 1001], dtype=int64),
#  942: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 939, 940, 943, 985,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  943: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 985,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  944: array([227, 226, 224, 222, 221, 220, 228, 219], dtype=int64),
#  945: array([959, 974, 955, 954, 953, 952, 951, 950, 949, 948, 947, 946, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  946: array([959, 974, 955, 954, 953, 952, 951, 950, 949, 948, 947, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  947: array([959, 974, 955, 954, 953, 952, 951, 950, 949, 948, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  948: array([959, 974, 955, 954, 953, 952, 951, 950, 949, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  949: array([959, 974, 955, 954, 953, 952, 951, 950, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  950: array([959, 974, 955, 954, 953, 952, 951, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  951: array([959, 974, 955, 954, 953, 952, 950, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  952: array([636, 637, 638, 923, 942, 939, 940, 943, 985, 934, 924, 932, 925,
#         933, 926, 960, 959, 974, 955, 954, 951, 950, 949, 948, 947, 946,
#         945, 991, 929, 628], dtype=int64),
#  953: array([960, 959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 991,
#         628], dtype=int64),
#  954: array([959, 974, 955, 953, 952, 951, 950, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  955: array([959, 974, 954, 953, 952, 951, 950, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  956: array([], dtype=int64),
#  957: array([958], dtype=int64),
#  958: array([957], dtype=int64),
#  959: array([974, 955, 954, 953, 952, 951, 950, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  960: array([953, 952, 991, 628], dtype=int64),
#  961: array([963, 962, 979, 977, 964, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  962: array([963, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  963: array([962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  964: array([963, 962, 979, 961, 977, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  965: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  966: array([959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 929, 628,
#         984, 987, 967, 986], dtype=int64),
#  967: array([959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 929, 628,
#         984, 966, 987, 986], dtype=int64),
#  968: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 980,
#         996, 997, 998, 999], dtype=int64),
#  969: array([640, 650, 970, 990], dtype=int64),
#  970: array([640, 650, 969, 990], dtype=int64),
#  971: array([], dtype=int64),
#  972: array([930, 927, 928, 937, 938, 636, 637, 638, 923, 942, 939, 940, 943,
#         985, 934, 924, 932, 933], dtype=int64),
#  973: array([], dtype=int64),
#  974: array([959, 955, 954, 953, 952, 951, 950, 949, 948, 947, 946, 945, 929,
#         628, 984, 966, 987, 967, 986], dtype=int64),
#  975: array([1558, 1554], dtype=int64),
#  976: array([963, 962, 979, 961, 977, 964, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  977: array([963, 962, 979, 961, 964, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  978: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  979: array([963, 962, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  980: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968,
#         996, 997, 998, 999], dtype=int64),
#  981: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  982: array([1534, 1604, 1597], dtype=int64),
#  983: array([1446, 1419, 1420, 1377, 1387, 1438, 1433, 1378, 1376, 1421, 1379,
#         1357, 1356, 1358, 1380], dtype=int64),
#  984: array([959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 929, 628,
#         966, 987, 967, 986], dtype=int64),
#  985: array([927, 928, 937, 938, 972, 636, 637, 638, 923, 942, 939, 940, 943,
#         934, 924, 932, 925, 933, 926, 952, 991], dtype=int64),
#  986: array([959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 929, 628,
#         984, 966, 987, 967], dtype=int64),
#  987: array([959, 974, 955, 954, 951, 950, 949, 948, 947, 946, 945, 929, 628,
#         984, 966, 967, 986], dtype=int64),
#  988: array([252, 236, 253, 237, 286, 251, 235, 238, 239], dtype=int64),
#  989: array([], dtype=int64),
#  990: array([640, 650, 969, 970], dtype=int64),
#  991: array([636, 637, 638, 923, 942, 939, 940, 943, 985, 934, 924, 932, 925,
#         933, 926, 960, 953, 952, 929, 628], dtype=int64),
#  992: array([963, 962, 979, 961, 977, 964, 976, 936, 965, 981, 978, 968, 980,
#         996, 997, 998, 999], dtype=int64),
#  993: array([633, 634, 994, 643, 641, 995, 879, 657, 642], dtype=int64),
#  994: array([633, 634, 643, 641, 995, 993, 879, 657, 642], dtype=int64),
#  995: array([633, 634, 994, 643, 641, 993, 879, 657, 642], dtype=int64),
#  996: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968,
#         980, 997, 998, 999], dtype=int64),
#  997: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968,
#         980, 996, 998, 999], dtype=int64),
#  998: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968,
#         980, 996, 997, 999], dtype=int64),
#  999: array([963, 962, 979, 961, 977, 964, 976, 992, 936, 965, 981, 978, 968,
#         980, 996, 997, 998], dtype=int64),
#  ...}

# %%
# Ensure all neighbours are valid indices
valid_indices = set(merged_data.index)
neighbours = {k: [idx for idx in v if idx in valid_indices] for k, v in neighbours.items() if k in valid_indices}

# %%
# Function to calculate outlier scores
def calculate_outlier_scores(data, neighbours, parties):
    outlier_scores = np.zeros((data.shape[0], len(parties)))
    for party_index, party in enumerate(parties):
        for unit_index, neighbour_indices in neighbours.items():
            try:
                unit_votes = data.at[unit_index, party]
                if neighbour_indices:
                    neighbour_votes = data.loc[neighbour_indices, party].values
                    if len(neighbour_votes) > 0:
                        mean_neighbour_votes = np.mean(neighbour_votes)
                        outlier_score = abs(unit_votes - mean_neighbour_votes)
                        outlier_scores[unit_index, party_index] = outlier_score
                    else:
                        outlier_scores[unit_index, party_index] = np.nan
                else:
                    outlier_scores[unit_index, party_index] = np.nan
            except KeyError as e:
                print(f"KeyError: {e} - Skipping index {unit_index} for party {party}")
                outlier_scores[unit_index, party_index] = np.nan
    outlier_scores_df = pd.DataFrame(outlier_scores, columns=[party + '_outlier_score' for party in parties])
    return outlier_scores_df

# %%
# Measure execution time
start_time = time.time()

# Calculate outlier scores for each party
parties = ['APC', 'LP', 'PDP', 'NNPP']

outlier_scores_df = calculate_outlier_scores(merged_data, neighbours, parties)

end_time = time.time()
print("Execution Time: ", end_time - start_time, " seconds")
# Out:
# Execution Time:  1.3884646892547607  seconds

# %%
outlier_scores_df
# Out:
#       APC_outlier_score  LP_outlier_score  PDP_outlier_score  \
# 0             48.200000        267.600000         115.200000
# 1             32.461538          5.153846          59.692308
# 2             78.000000          2.500000           2.500000
# 3                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# ...                 ...               ...                ...
# 1965         102.909091          6.590909          68.500000
# 1966          62.303030          8.636364          25.863636
# 1967          93.410256          4.820513          36.102564
# 1968         114.948718          3.794872          42.256410
# 1969         129.307692          7.897436          46.358974
#
#       NNPP_outlier_score
# 0               0.200000
# 1               1.000000
# 2               1.000000
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1965            1.863636
# 1966            0.166667
# 1967            0.282051
# 1968            0.282051
# 1969            0.743590
#
# [1970 rows x 4 columns]

# %%
# Alternatively, fill NaN values with the median of each column
outlier_scores_df.fillna(outlier_scores_df.median(), inplace=True)

# %%
outlier_scores_df
# Out:
#       APC_outlier_score  LP_outlier_score  PDP_outlier_score  \
# 0             48.200000        267.600000         115.200000
# 1             32.461538          5.153846          59.692308
# 2             78.000000          2.500000           2.500000
# 3             30.000000          2.800000          30.939394
# 4             30.000000          2.800000          30.939394
# ...                 ...               ...                ...
# 1965         102.909091          6.590909          68.500000
# 1966          62.303030          8.636364          25.863636
# 1967          93.410256          4.820513          36.102564
# 1968         114.948718          3.794872          42.256410
# 1969         129.307692          7.897436          46.358974
#
#       NNPP_outlier_score
# 0               0.200000
# 1               1.000000
# 2               1.000000
# 3               0.115385
# 4               0.115385
# ...                  ...
# 1965            1.863636
# 1966            0.166667
# 1967            0.282051
# 1968            0.282051
# 1969            0.743590
#
# [1970 rows x 4 columns]

# %%
merged_data = pd.concat([merged_data, outlier_scores_df], axis=1)
merged_data.head(2)
# Out:
#   State             LGA   Ward       PU-Code              PU-Name  \
# 0  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-001      TOWN HALL IWARA
# 1  OSUN  ATAKUMOSA EAST  IWARA  29-01-01-003  L.A. SCHOOL, IWIKUN
#
#    Accredited_Voters  Registered_Voters  APC   LP  PDP  NNPP  Latitude  \
# 0                181                942   44  273    0     0  7.466182
# 1                245                881   40   11  175     1  7.586975
#
#    Longitude  Latitude_rad  Longitude_rad  APC_outlier_score  \
# 0   4.678075      0.130309       0.081648          48.200000
# 1   4.629450      0.132418       0.080799          32.461538
#
#    LP_outlier_score  PDP_outlier_score  NNPP_outlier_score
# 0        267.600000         115.200000                 0.2
# 1          5.153846          59.692308                 1.0

# %%
# Save the merged data with outlier scores
output_file = 'OSUN_cleaned_election_data_with_outlier_scores.csv'
merged_data.to_csv(output_file, index=False)

# %%
# # Save the merged data with outlier scores
# merged_data.to_csv('osun_cleaned_election_data_with_outlier_scores.csv', index=False)

# %% [markdown]
# ## Visualize Outliers using box plots

# %%
# Function to save and display box plots
def save_and_display_box_plots(data, parties, filename):
    plt.figure(figsize=(10, 7))
    data_to_plot = [data[party + '_outlier_score'].dropna() for party in parties]
    plt.boxplot(data_to_plot, labels=parties, patch_artist=True)
    plt.title('Outlier Scores for Each Party')
    plt.xlabel('Party')
    plt.ylabel('Outlier Score')
    plt.savefig(filename)
    plt.show()
    plt.close()

# %%
# Save and display box plot image
save_and_display_box_plots(merged_data, parties, 'OSUN_outlier_scores_boxplot.png')

# %%
# Function to save and display scatter plots
def save_and_display_scatter_plots(data, parties, filename_prefix):
    for party in parties:
        plt.figure(figsize=(12, 8))
        norm = plt.Normalize(data[party + '_outlier_score'].min(), data[party + '_outlier_score'].max())
        sm = plt.cm.ScalarMappable(cmap="coolwarm", norm=norm)
        sm.set_array([])
        
        sns.scatterplot(
            x=data['Longitude'], 
            y=data['Latitude'], 
            hue=data[party + '_outlier_score'], 
            palette='coolwarm', 
            s=100, 
            edgecolor='k',
            norm=norm
        )
        plt.title(f'Scatter Plot of Outlier Scores for {party}')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.colorbar(sm, label='Outlier Score')
        plt.savefig(f'{filename_prefix}_{party}_scatter.png')
        plt.show()
        plt.close()

# Save and display scatter plot images
save_and_display_scatter_plots(merged_data, parties, 'OSUN_outlier_scores_scatter')

# %% [markdown]
# ## Step 2: Visualize Outliers on a Map
#
# - Create an interactive map using folium and add markers for each party, highlighting the outliers.

# %%
# Initialize the map centered around Delta State
map_center = [merged_data['Latitude'].mean(), merged_data['Longitude'].mean()]
election_map = folium.Map(location=map_center, zoom_start=10)

# %%
# Create a marker cluster
marker_cluster = MarkerCluster().add_to(election_map)

# %%
# Function to add markers to the map
def add_markers(map_object, data, party):
    for _, row in data.iterrows():
        outlier_score = row[party + '_outlier_score']
        color = 'red' if outlier_score > data[party + '_outlier_score'].mean() + 2 * data[party + '_outlier_score'].std() else 'blue'
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"Polling Unit: {row['PU-Code']}, Outlier Score: {outlier_score}",
            icon=folium.Icon(color=color)
        ).add_to(map_object)

# %%
# Add markers for each party
for party in parties:
    add_markers(marker_cluster, merged_data, party)

# %%
# Save the Folium map as an HTML file
map_filename = 'OSUN_election_outliers_map.html'
election_map.save(map_filename)

# %%
# Function to capture a screenshot of the map
def save_folium_map_as_image(map_filename, image_filename):
    # Set up the web driver (Chrome)
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)

    # Load the HTML file
    driver.get('file://' + os.path.abspath(map_filename))
    time.sleep(5)  # Give the map some time to render

    # Capture the screenshot
    driver.save_screenshot('map_screenshot.png')
    driver.quit()

    # Crop the image (optional, to remove browser window borders)
    with Image.open('map_screenshot.png') as img:
        img = img.crop((10, 10, img.width - 10, img.height - 10))
        img.save(image_filename)

# Save and display the Folium map as an image
save_folium_map_as_image(map_filename, 'OSUN_election_outliers_map.png')
display(IFrame(map_filename, width=700, height=500))
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="OSUN_election_outliers_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Sort the dataset by outlier scores for each party
sorted_data_apc = merged_data.sort_values(by='APC_outlier_score', ascending=False)
sorted_data_lp = merged_data.sort_values(by='LP_outlier_score', ascending=False)
sorted_data_pdp = merged_data.sort_values(by='PDP_outlier_score', ascending=False)
sorted_data_nnpp = merged_data.sort_values(by='NNPP_outlier_score', ascending=False)

# %%
# Display top 3 outliers for each party
print("Top 3 outliers for APC:")
sorted_data_apc.head(3)
# Out:
#      State        LGA             Ward       PU-Code  \
# 1883  OSUN     OSOGBO         JAGUN B'  29-30-10-005
# 307   OSUN  EDE NORTH  OLOGUN/AGBAAKIN  29-07-03-004
# 724   OSUN   IFE EAST    MODAKEKE  III  29-13-10-001
#
#                                                 PU-Name  Accredited_Voters  \
# 1883                                    JIMMY RADIO  II                111
# 307   OPEN SPACE IN FRONT OF BAALE ILE ARANYIN( ARAN...                332
# 724                       OGUNSUA GRAM. SCHOOL, ESUYARE                498
#
#       Registered_Voters  APC  LP  PDP  NNPP  Latitude  Longitude  \
# 1883                239   54   1   56     0  7.776720   4.589650
# 307                 750  287   0   23     0  7.734928   4.443937
# 724                2096  292  43  137     0  7.480880   4.525433
#
#       Latitude_rad  Longitude_rad  APC_outlier_score  LP_outlier_score  \
# 1883      0.135729       0.080104         224.500000          0.500000
# 307       0.135000       0.077561         217.130435          2.130435
# 724       0.130566       0.078984         198.000000         36.250000
#
#       PDP_outlier_score  NNPP_outlier_score
# 1883          71.500000             0.00000
# 307          136.043478             0.26087
# 724           72.000000             0.00000

# %%
print("\nTop 3 outliers for LP:")
sorted_data_lp.head(3)
# Out:
#     State             LGA               Ward       PU-Code  \
# 448  OSUN          EJIGBO  ELEJIGBO 'C'/MAPO  29-10-03-001
# 0    OSUN  ATAKUMOSA EAST              IWARA  29-01-01-001
# 5    OSUN  ATAKUMOSA EAST            IGANGAN  29-01-02-003
#
#                             PU-Name  Accredited_Voters  Registered_Voters  \
# 448     BEULAH BAPT. SCHOOL, EJIGBO                288                750
# 0                   TOWN HALL IWARA                181                942
# 5    APOSTOLIC PRY. SCHOOL, OKO-AGO                204                724
#
#      APC   LP  PDP  NNPP  Latitude  Longitude  Latitude_rad  Longitude_rad  \
# 448    1  400    1     2  7.907559   4.316765      0.138013       0.075342
# 0     44  273    0     0  7.466182   4.678075      0.130309       0.081648
# 5      3  199    0     0  7.469135   4.542204      0.130361       0.079276
#
#      APC_outlier_score  LP_outlier_score  PDP_outlier_score  \
# 448         143.368421        391.684211         108.842105
# 0            48.200000        267.600000         115.200000
# 5            99.600000        192.100000          75.100000
#
#      NNPP_outlier_score
# 448            1.894737
# 0              0.200000
# 5              1.000000

# %%
print("\nTop 3 outliers for PDP:")
sorted_data_pdp.head(3)
# Out:
#      State        LGA                 Ward       PU-Code  \
# 321   OSUN  EDE NORTH            ALUSEKERE  29-07-05-004
# 1927  OSUN     BORIPE  COLLEGE/EGBADA ROAD  29-06-03-016
# 953   OSUN        ILA             ISEDO  I  29-17-04-013
#
#                                 PU-Name  Accredited_Voters  Registered_Voters  \
# 321             OWODE COMM. PRY SCHOOL,                771               2543
# 1927  OPEN SPACE BY OWODE MARKET SQUARE                196                596
# 953                         SECRETARIAT                497                887
#
#       APC   LP  PDP  NNPP  Latitude  Longitude  Latitude_rad  Longitude_rad  \
# 321   217  147  380     2  7.715233   4.486008      0.134656       0.078296
# 1927  102    0   68     0  7.713541   4.488894      0.134627       0.078346
# 953   144    3  328     1  8.011101   4.912681      0.139820       0.085742
#
#       APC_outlier_score  LP_outlier_score  PDP_outlier_score  \
# 321          115.000000        147.000000         312.000000
# 1927         115.000000        147.000000         312.000000
# 953           65.214286          1.571429         244.142857
#
#       NNPP_outlier_score
# 321             2.000000
# 1927            2.000000
# 953             6.642857

# %%
print("\nTop 3 outliers for NNPP:")
sorted_data_nnpp.head(3)
# Out:
# Top 3 outliers for NNPP:
#     State        LGA              Ward       PU-Code              PU-Name  \
# 363  OSUN  EDE SOUTH          ALAJUE I  29-08-04-006              ODE-OKE
# 333  OSUN  EDE NORTH  SABO/AGBONGBE II  29-07-07-001  BESIDE EBELOMO IND.
# 945  OSUN        ILA          ISEDO  I  29-17-04-001           OLOPONDA I
#
#      Accredited_Voters  Registered_Voters  APC  LP  PDP  NNPP  Latitude  \
# 363                335                833  113   3    0   207  7.720236
# 333                194                750   50  14    0   127  7.744758
# 945                198                370   87   2    0   106  8.018623
#
#      Longitude  Latitude_rad  Longitude_rad  APC_outlier_score  \
# 363   4.450365      0.134744       0.077674          44.250000
# 333   4.437060      0.135172       0.077441          16.500000
# 945   4.913126      0.139951       0.085750           1.631579
#
#      LP_outlier_score  PDP_outlier_score  NNPP_outlier_score
# 363          8.500000         217.750000          207.000000
# 333         12.055556         121.388889          126.833333
# 945          0.736842         116.368421          105.842105

# %%
print(sorted_data_nnpp.head(3))
# Out:
#     State        LGA              Ward       PU-Code              PU-Name  \
# 363  OSUN  EDE SOUTH          ALAJUE I  29-08-04-006              ODE-OKE
# 333  OSUN  EDE NORTH  SABO/AGBONGBE II  29-07-07-001  BESIDE EBELOMO IND.
# 945  OSUN        ILA          ISEDO  I  29-17-04-001           OLOPONDA I
#
#      Accredited_Voters  Registered_Voters  APC  LP  PDP  NNPP  Latitude  \
# 363                335                833  113   3    0   207  7.720236
# 333                194                750   50  14    0   127  7.744758
# 945                198                370   87   2    0   106  8.018623
#
#      Longitude  Latitude_rad  Longitude_rad  APC_outlier_score  \
# 363   4.450365      0.134744       0.077674          44.250000
# 333   4.437060      0.135172       0.077441          16.500000
# 945   4.913126      0.139951       0.085750           1.631579
#
#      LP_outlier_score  PDP_outlier_score  NNPP_outlier_score
# 363          8.500000         217.750000          207.000000
# 333         12.055556         121.388889          126.833333
# 945          0.736842         116.368421          105.842105

# %%
osun_data.to_csv('cleaned_OSUN_data.csv', index=False)

# %%
# Save the sorted lists to an Excel file
with pd.ExcelWriter('sorted_outliers.xlsx') as writer:
    sorted_data_apc.to_excel(writer, sheet_name='APC', index=False)
    sorted_data_lp.to_excel(writer, sheet_name='LP', index=False)
    sorted_data_pdp.to_excel(writer, sheet_name='PDP', index=False)
    sorted_data_nnpp.to_excel(writer, sheet_name='NNPP', index=False)

# %%
## Outlier Detection in Election Data Using Geospatial Analysis

### 1. Introduction
In the recently concluded election, allegations of vote manipulation have prompted a thorough investigation into the integrity of the results. This report aims to uncover potential voting irregularities by identifying outlier polling units where voting results significantly deviate from neighbouring units.

### 2. Methodology
**Dataset Preparation**: We loaded the Delta State election data and merged it with polling unit data containing geographical coordinates (latitude and longitude).

**Neighbour Identification**: Using the `BallTree` method, we identified neighbouring polling units within a 1 km radius based on geographical proximity.

**Outlier Score Calculation**: For each polling unit, we calculated the outlier score for each party (APC, LP, PDP, NNPP) based on the deviation of votes from neighbouring units. The outlier score is the absolute difference between the unit’s votes and the average votes of its neighbours.

### 3. Findings
**Top 3 Outliers for APC**:
1. Polling Unit XYZ: Outlier Score = 50
2. Polling Unit ABC: Outlier Score = 45
3. Polling Unit DEF: Outlier Score = 40

**Top 3 Outliers for LP**:
1. Polling Unit XYZ: Outlier Score = 55
2. Polling Unit ABC: Outlier Score = 50
3. Polling Unit DEF: Outlier Score = 45

... (continue for PDP and NNPP)

### 4. Visualizations
**Map of Election Outliers**:
Include the map generated using `folium` showing polling units with significant outlier scores.

### 5. Conclusion
The analysis identified several polling units with significant deviations in voting patterns, indicating potential irregularities. These findings warrant further investigation to ensure the integrity of the election results. Future steps should include a closer examination of the identified outliers and potential corrective measures.

# %%
# Extract latitude and longitude columns
lat_lon = merged_data[['Latitude', 'Longitude']].values

# Convert latitude and longitude to radians for BallTree
lat_lon_rad = np.radians(lat_lon)

# Create a BallTree for fast spatial queries
tree = BallTree(lat_lon_rad, metric='haversine')

# Define the radius for neighbors (in radians)
radius_km = 1.0
radius_rad = radius_km / 6371.0  # Earth's radius in kilometers

# Function to find neighbors using BallTree
def find_neighbours_balltree(tree, coords, radius):
    neighbours = {}
    for i, coord in enumerate(coords):
        indices = tree.query_radius([coord], r=radius)[0]
        neighbours[i] = indices[indices != i]  
    return neighbours

# Find neighbors using BallTree
neighbours = find_neighbours_balltree(tree, lat_lon_rad, radius_rad)
